# %%
import os
import pandas as pd
import glob
import openpyxl

# %%
dir = '../Es5/file/file_csv'
fileListCsv=os.listdir(dir)
fileListCsv

# %%
df_append = pd.DataFrame()

for file in fileListCsv:
    df_temp = pd.read_csv(file)
    df_append = df_append.append(df_temp)

# %%
df_concat = pd.concat([pd.read_csv(file) for file in fileListCsv], ignore_index=True)
df_concat

# %%
csv_files = glob.glob('../Es5/file/file_csv/*.csv')
csv_files
# Out:
# ['../Es5/file/file_csv\\Abruzzo.csv',
#  '../Es5/file/file_csv\\Basilicata.csv',
#  '../Es5/file/file_csv\\Calabria.csv',
#  '../Es5/file/file_csv\\Campania.csv',
#  '../Es5/file/file_csv\\Centro.csv',
#  '../Es5/file/file_csv\\Emilia_Romagna.csv',
#  '../Es5/file/file_csv\\Friuli_Venezia_Giulia.csv',
#  '../Es5/file/file_csv\\Italia.csv',
#  '../Es5/file/file_csv\\Lazio.csv',
#  '../Es5/file/file_csv\\Liguria.csv',
#  '../Es5/file/file_csv\\Lombardia.csv',
#  '../Es5/file/file_csv\\Marche.csv',
#  '../Es5/file/file_csv\\Mezzogiorno.csv',
#  '../Es5/file/file_csv\\Molise.csv',
#  '../Es5/file/file_csv\\Nord_est.csv',
#  '../Es5/file/file_csv\\Nord_ovest.csv',
#  '../Es5/file/file_csv\\Piemonte.csv',
#  '../Es5/file/file_csv\\Provincia_Autonoma_Bolzano__Bozen.csv',
#  '../Es5/file/file_csv\\Provincia_Autonoma_Trento.csv',
#  '../Es5/file/file_csv\\Puglia.csv',
#  '../Es5/file/file_csv\\Sardegna.csv',
#  '../Es5/file/file_csv\\Sicilia.csv',
#  '../Es5/file/file_csv\\Toscana.csv',
# ...

# %%
df_concat = pd.concat([pd.read_csv(file) for file in csv_files], ignore_index=True)
df_concat

# %%
df_concat.to_csv("../Es5/file/new.csv")

# %%
xlsx_files = glob.glob('../Es5/file/file_xlsx/*.xlsx')
xlsx_files
# Out:
# ['../Es5/file/file_xlsx\\Abruzzo.xlsx',
#  '../Es5/file/file_xlsx\\Basilicata.xlsx',
#  '../Es5/file/file_xlsx\\Calabria.xlsx',
#  '../Es5/file/file_xlsx\\Campania.xlsx',
#  '../Es5/file/file_xlsx\\Centro.xlsx',
#  '../Es5/file/file_xlsx\\Emilia_Romagna.xlsx',
#  '../Es5/file/file_xlsx\\Friuli_Venezia_Giulia.xlsx',
#  '../Es5/file/file_xlsx\\Italia.xlsx',
#  '../Es5/file/file_xlsx\\Lazio.xlsx',
#  '../Es5/file/file_xlsx\\Liguria.xlsx',
#  '../Es5/file/file_xlsx\\Lombardia.xlsx',
#  '../Es5/file/file_xlsx\\Marche.xlsx',
#  '../Es5/file/file_xlsx\\Mezzogiorno.xlsx',
#  '../Es5/file/file_xlsx\\Molise.xlsx',
#  '../Es5/file/file_xlsx\\Nord_est.xlsx',
#  '../Es5/file/file_xlsx\\Nord_ovest.xlsx',
#  '../Es5/file/file_xlsx\\Piemonte.xlsx',
#  '../Es5/file/file_xlsx\\Provincia_Autonoma_Bolzano__Bozen.xlsx',
#  '../Es5/file/file_xlsx\\Provincia_Autonoma_Trento.xlsx',
#  '../Es5/file/file_xlsx\\Puglia.xlsx',
#  '../Es5/file/file_xlsx\\Sardegna.xlsx',
#  '../Es5/file/file_xlsx\\Sicilia.xlsx',
# ...

# %%
df_concat = pd.concat([pd.read_excel(file) for file in xlsx_files], ignore_index=True)
df_concat
# Out:
#      Unnamed: 0 ITTER107 Territorio  TIPO_DATO_CENERG  \
# 0           215     ITF1    Abruzzo     ENER_SOUR_EXP
# 1           216     ITF1    Abruzzo     ENER_SOUR_EXP
# 2           217     ITF1    Abruzzo     ENER_SOUR_EXP
# 3           218     ITF1    Abruzzo     ENER_SOUR_EXP
# 4           219     ITF1    Abruzzo     ENER_SOUR_EXP
# ..          ...      ...        ...               ...
# 296         122     ITD3     Veneto  ENER_SOUR_EXP_AV
# 297         123     ITD3     Veneto  ENER_SOUR_EXP_AV
# 298         124     ITD3     Veneto  ENER_SOUR_EXP_AV
# 299         125     ITD3     Veneto  ENER_SOUR_EXP_AV
# 300         126     ITD3     Veneto  ENER_SOUR_EXP_AV
#
#                                              Tipo dato DOTAZIONI_A  \
# 0    spese delle famiglie per consumi energetici pe...         ALL
# 1    spese delle famiglie per consumi energetici pe...       H_OIL
# 2    spese delle famiglie per consumi energetici pe...         LPG
# ...

# %%
df_concat.to_csv("../Es5/file/new.xlsx")
